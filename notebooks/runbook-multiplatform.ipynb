# %% [markdown]
# <a href="https://colab.research.google.com/github/aio25-mix002/m07-p7.1/blob/main/notebooks/runbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# ## Checking

# %%
import os
from pathlib import Path

def notebook_runtime() -> str:
    # Kaggle
    if any(k in os.environ for k in ("KAGGLE_URL_BASE", "KAGGLE_KERNEL_RUN_TYPE", "KAGGLE_DATA_PROXY_TOKEN")):
        return "kaggle"

    # Google Colab
    if "COLAB_RELEASE_TAG" in os.environ or "COLAB_GPU" in os.environ:
        return "colab"

    # Local / other Jupyter (VS Code, JupyterLab, etc.)
    return "local"

NOTEBOOK_RUNTIME = notebook_runtime()
print("Runtime:", NOTEBOOK_RUNTIME)
# Out:
# Runtime: colab

# %% [markdown]
# ## Configuration

# %%
from dotenv import load_dotenv

SAVE_TO_REMOTE_STORAGE = True
ROOT_DIR = None
CODE_DIR = None
INPUT_DATA_DIR = None
OUTPUT_DIR = None
APPCONFIG_ENV_FILENAME = None

if NOTEBOOK_RUNTIME == "kaggle":
    SAVE_TO_REMOTE_STORAGE = False
    ROOT_DIR = Path("/kaggle/")
    CODE_DIR = ROOT_DIR / "temp/src"
    INPUT_DATA_DIR = ROOT_DIR / "input/action-video/data"
    APPCONFIG_ENV_FILENAME = ".env.kaggle"


elif NOTEBOOK_RUNTIME == "colab":
    from google.colab import output
    output.enable_custom_widget_manager()
    SAVE_TO_REMOTE_STORAGE = True
    ROOT_DIR = Path("/content")
    CODE_DIR = ROOT_DIR / "src"
    INPUT_DATA_DIR = ROOT_DIR / "kaggle/competitions/action-video/data/data_train"

    # Configure runtime via environment variables
    os.environ['KAGGLEHUB_CACHE'] = str(ROOT_DIR / "kaggle")
    os.environ['KAGGLE_CONFIG_DIR'] = str(ROOT_DIR / ".kaggle")
    os.environ['APPCONFIG__DATA_ROOT'] = str(INPUT_DATA_DIR)
    os.environ['APPCONFIG__TEST_DATA_ROOT'] = str(ROOT_DIR / "kaggle/competitions/action-video/data/test")
    os.environ['APPCONFIG__CHECKPOINT_DIR'] = str(ROOT_DIR / "drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints")
    os.environ['APPCONFIG__WEIGHTS_DIR'] = str(ROOT_DIR / "temp/weights")
    os.environ['APPCONFIG__EPOCHS'] = str(10)
    os.environ['APPCONFIG__PATIENCE'] = str(10)
    os.environ['APPCONFIG__BATCH_SIZE'] = str(32)
    os.environ['APPCONFIG__NUM_WORKERS'] = str(8)
    #os.environ['APPCONFIG__BATCH_SIZE'] = str(8)
    #os.environ['APPCONFIG__NUM_WORKERS'] = str(4)

else:
    SAVE_TO_REMOTE_STORAGE = False

    # Init root dir once as the working dir can be changed after than.
    if ROOT_DIR is None:
        ROOT_DIR = (Path.cwd().parent).absolute()
    CODE_DIR = ROOT_DIR
    INPUT_DATA_DIR = ROOT_DIR / "kaggle/competitions/action-video/data"
    APPCONFIG_ENV_FILENAME = ".env.local"


os.environ['APPCONFIG__EXPR_NAME'] = "default_expr"
print(f"[Done] Configuring {NOTEBOOK_RUNTIME}")
# Out:
# [Done] Configuring colab

# %%
print("Root Directory:", ROOT_DIR)
for item in os.listdir(ROOT_DIR):
    print(f"{item}")
# Out:
# Root Directory: /content
# .config
# sample_data

# %% [markdown]
# ## Connect to a shared storage

# %%
if NOTEBOOK_RUNTIME == "colab":
    from google.colab import drive
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download code

# %%
# If directory "src" not exist then clone a new one
# !pwd
![ -d "{CODE_DIR}" ] || git clone --depth 1  --branch "users/hung-doan/000-update-notebook-log-3" "https://github.com/aio25-mix002/m07-p7.1" "{CODE_DIR}"
# Out:
# /content
# Cloning into '/content/src'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 21 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 148.57 KiB | 5.31 MiB/s, done.

# %% [markdown]
# ## Fetch the latest code

# %%
# Go to CODE_DIR, Fetch the latest code
# %cd {CODE_DIR}
# !git clean -fdx
# !git status
# !git pull
# !pwd
# Out:
# /content/src
# Removing logs/
# Removing src/__pycache__/
# On branch users/hung-doan/000-update-notebook-log-3
# Your branch is up to date with 'origin/users/hung-doan/000-update-notebook-log-3'.
#
# nothing to commit, working tree clean
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 642 bytes | 642.00 KiB/s, done.
# From https://github.com/aio25-mix002/m07-p7.1
#    72e985a..32fe3b2  users/hung-doan/000-update-notebook-log-3 -> origin/users/hung-doan/000-update-notebook-log-3
# Updating 72e985a..32fe3b2
# Fast-forward
#  src/utils.py | 10 ++++++++++
#  1 file changed, 10 insertions(+)
# /content/src

# %% [markdown]
# ## Restore packages

# %%
#!uv sync
# %cd {CODE_DIR}
# !uv pip install -r pyproject.toml
# Out:
# /content/src
# Using Python 3.12.12 environment at: /usr
# Resolved 84 packages in 682ms
# Prepared 9 packages in 265ms
# Uninstalled 5 packages in 18ms
# Installed 9 packages in 43ms
#  + comm==0.2.3
#  - ipykernel==6.17.1
#  + ipykernel==7.1.0
#  - ipywidgets==7.7.1
#  + ipywidgets==8.1.8
#  + jedi==0.19.2
#  - jupyter-client==7.4.9
#  + jupyter-client==8.8.0
#  - kagglehub==0.3.13
#  + kagglehub==0.4.0
#  + kagglesdk==0.1.14
#  + loguru==0.7.3
#  - widgetsnbextension==3.6.10
#  + widgetsnbextension==4.0.15

# %% [markdown]
# # Data Preparation

# %%
import kagglehub
import getpass
if NOTEBOOK_RUNTIME != "kaggle" and os.environ["KAGGLE_API_TOKEN"] is None:
    # kagglehub.login()
    # OR
    # os.environ["KAGGLE_API_TOKEN"] = "<YOUR TOKEN>"

    os.environ["KAGGLE_API_TOKEN"] = getpass.getpass()
# Out:
# ··········

# %%
#

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
import subprocess
import sys
os.chdir(CODE_DIR)
if NOTEBOOK_RUNTIME != "kaggle":
    # To Download Kaggle competition you should setup your credential in .kaggle/kaggle.json
    # run the script with the same Python interpreter as the notebook
    # subprocess.check_call([sys.executable, f"{CODE_DIR}/download_data_from_kaggle.py"])
    import kagglehub
    kagglehub.competition_download('action-video')
# Out:
# Downloading to /content/kaggle/competitions/action-video.archive...
# 100%|██████████| 3.14G/3.14G [01:28<00:00, 38.1MB/s]
# Extracting files...

# %% [markdown]
# # Train

# %%
os.chdir(CODE_DIR)

# %%
from src.config import ModelConfig, TrainingConfig
ModelConfig().reload()
TrainingConfig().reload()

# %%
if not load_dotenv(dotenv_path= CODE_DIR / f"./{APPCONFIG_ENV_FILENAME}"):
    print(f"Warning: No {APPCONFIG_ENV_FILENAME} file found in {CODE_DIR}")
else:
    print("Loaded the environment variables")
# Out:
# Warning: No None file found in /content/src

# %%
# !python -u ./train.py
# Out:
# 2026-01-10 20:07:53.814 | INFO     | src.logging_utils:info:42 - EXPR NAME: default_expr
# 2026-01-10 20:07:53.814 | INFO     | src.logging_utils:info:42 - Using device: cuda
# 2026-01-10 20:07:53.814 | INFO     | src.logging_utils:info:42 - Initializing datasets...
# 2026-01-10 20:07:57.652 | INFO     | src.logging_utils:info:42 - Train size: 5645 | Val size: 609
# 2026-01-10 20:07:57.652 | INFO     | src.logging_utils:info:42 - Creating model...
# Inflated patch_embed.proj.weight from 2D to 3D: torch.Size([768, 3, 16, 16]) -> torch.Size([768, 3, 2, 16, 16])
# Loaded pretrained weights. Missing: 133, Unexpected: 0
# 2026-01-10 20:07:58.810 | INFO     | src.logging_utils:info:42 - 🚀 Compiling model with torch.compile...
# 2026-01-10 20:08:02.233 | INFO     | src.logging_utils:info:42 - Backbone FROZEN (Chỉ train SMIF & Head)
# 2026-01-10 20:08:02.233 | INFO     | src.logging_utils:info:42 -
# Epoch 1/10
# Train:   0% 0/177 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/backends/cuda/__init__.py:131: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return torch._C._get_cublas_allow_tf32()
# Val:   0% 0/20 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:312: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# 2026-01-10 20:14:18.622 | INFO     | src.logging_utils:info:42 - Train Loss: 3.7387 | Acc: 0.0829
# 2026-01-10 20:14:18.622 | INFO     | src.logging_utils:info:42 - Val Loss: 3.7578   | Acc: 0.0788
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:14:19.490 | INFO     | src.logging_utils:info:42 - New best model saved! (0.0788)
# 2026-01-10 20:14:19.491 | INFO     | src.logging_utils:info:42 - Backbone FROZEN (Chỉ train SMIF & Head)
# 2026-01-10 20:14:19.491 | INFO     | src.logging_utils:info:42 -
# Epoch 2/10
# 2026-01-10 20:16:12.674 | INFO     | src.logging_utils:info:42 - Train Loss: 3.2605 | Acc: 0.1950
# 2026-01-10 20:16:12.674 | INFO     | src.logging_utils:info:42 - Val Loss: 3.4504   | Acc: 0.1593
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:16:13.686 | INFO     | src.logging_utils:info:42 - New best model saved! (0.1593)
# 2026-01-10 20:16:13.687 | INFO     | src.logging_utils:info:42 - Backbone FROZEN (Chỉ train SMIF & Head)
# 2026-01-10 20:16:13.687 | INFO     | src.logging_utils:info:42 -
# Epoch 3/10
# 2026-01-10 20:18:04.411 | INFO     | src.logging_utils:info:42 - Train Loss: 2.9670 | Acc: 0.2779
# 2026-01-10 20:18:04.411 | INFO     | src.logging_utils:info:42 - Val Loss: 3.2536   | Acc: 0.2053
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:18:05.370 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2053)
# 2026-01-10 20:18:05.371 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:18:05.371 | INFO     | src.logging_utils:info:42 -
# Epoch 4/10
# 2026-01-10 20:19:55.309 | INFO     | src.logging_utils:info:42 - Train Loss: 2.7583 | Acc: 0.3300
# 2026-01-10 20:19:55.310 | INFO     | src.logging_utils:info:42 - Val Loss: 3.1190   | Acc: 0.2430
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:19:56.305 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2430)
# 2026-01-10 20:19:56.306 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:19:56.306 | INFO     | src.logging_utils:info:42 -
# Epoch 5/10
# 2026-01-10 20:21:49.668 | INFO     | src.logging_utils:info:42 - Train Loss: 2.6021 | Acc: 0.3734
# 2026-01-10 20:21:49.668 | INFO     | src.logging_utils:info:42 - Val Loss: 3.0311   | Acc: 0.2463
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:21:50.603 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2463)
# 2026-01-10 20:21:50.605 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:21:50.605 | INFO     | src.logging_utils:info:42 -
# Epoch 6/10
# 2026-01-10 20:23:42.829 | INFO     | src.logging_utils:info:42 - Train Loss: 2.4795 | Acc: 0.3957
# 2026-01-10 20:23:42.829 | INFO     | src.logging_utils:info:42 - Val Loss: 2.9600   | Acc: 0.2693
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:23:43.823 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2693)
# 2026-01-10 20:23:43.824 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:23:43.824 | INFO     | src.logging_utils:info:42 -
# Epoch 7/10
# 2026-01-10 20:25:35.168 | INFO     | src.logging_utils:info:42 - Train Loss: 2.3850 | Acc: 0.4197
# 2026-01-10 20:25:35.168 | INFO     | src.logging_utils:info:42 - Val Loss: 2.9151   | Acc: 0.2791
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:25:36.119 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2791)
# 2026-01-10 20:25:36.120 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:25:36.120 | INFO     | src.logging_utils:info:42 -
# Epoch 8/10
# 2026-01-10 20:27:28.282 | INFO     | src.logging_utils:info:42 - Train Loss: 2.2987 | Acc: 0.4356
# 2026-01-10 20:27:28.282 | INFO     | src.logging_utils:info:42 - Val Loss: 2.8840   | Acc: 0.2841
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:27:29.257 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2841)
# 2026-01-10 20:27:29.258 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:27:29.258 | INFO     | src.logging_utils:info:42 -
# Epoch 9/10
# 2026-01-10 20:29:23.477 | INFO     | src.logging_utils:info:42 - Train Loss: 2.2287 | Acc: 0.4480
# 2026-01-10 20:29:23.477 | INFO     | src.logging_utils:info:42 - Val Loss: 2.8514   | Acc: 0.2890
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:29:24.427 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2890)
# 2026-01-10 20:29:24.429 | INFO     | src.logging_utils:info:42 - Backbone UN-FROZEN (Train toàn bộ)
# 2026-01-10 20:29:24.429 | INFO     | src.logging_utils:info:42 -
# Epoch 10/10
# 2026-01-10 20:31:17.108 | INFO     | src.logging_utils:info:42 - Train Loss: 2.1689 | Acc: 0.4636
# 2026-01-10 20:31:17.109 | INFO     | src.logging_utils:info:42 - Val Loss: 2.8484   | Acc: 0.2923
# Checkpoint saved to /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_200802_default_expr
# 2026-01-10 20:31:18.057 | INFO     | src.logging_utils:info:42 - New best model saved! (0.2923)

# %%
from src.config import ModelConfig, TrainingConfig
from src.utils import find_latest_checkpoint

t_cfg = TrainingConfig()
t_cfg.reload()
train_saved_chk_dir: str = find_latest_checkpoint(t_cfg.checkpoint_dir, t_cfg.expr_name)
print("Latest Checkpoint Location:", train_saved_chk_dir)
# Out:
# Found latest checkpoint: /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_091623_default_expr
# Latest Checkpoint Location: /content/drive/MyDrive/AIO25-MIX002/Projects/AIO2025_Conquer_CONQ008_M7_Project/Artifacts/Checkpoints/20260110_091623_default_expr

# %% [markdown]
# # Submission

# %% [markdown]
# ## Load model

# %%
import torch
from src.model import LSViTForAction

# Config
m_cfg = ModelConfig()
m_cfg.reload()
inf_model = LSViTForAction(config=m_cfg)

# Load the model checkpoint
checkpoint = torch.load(
    os.path.join(train_saved_chk_dir, "best_model.pth"), map_location=t_cfg.device
)

inf_model.load_state_dict(checkpoint['model'])
inf_model = inf_model.to(t_cfg.device)  # Move model to device
inf_model.eval()
print(f"Model loaded: trained acc: {checkpoint['val_acc']:.4f}; {len(checkpoint['train_classes'])} classes")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1599511070.py in <cell line: 0>()
#      12 )
#      13
# ---> 14 inf_model.load_state_dict(checkpoint['model'])
#      15 inf_model = inf_model.to(t_cfg.device)  # Move model to device
#      16 inf_model.eval()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2627
#    2628         if len(error_msgs) > 0:
# -> 2629             raise RuntimeError(
#    2630                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2631                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for LSViTForAction:
# 	Missing key(s) in state_dict: "backbone.temporal_embed".
# 	size mismatch for backbone.patch_embed.proj.weight: copying a param with shape torch.Size([768, 3, 16, 16]) from checkpoint, the shape in current model is torch.Size([768, 3, 2, 16, 16]).

# %% [markdown]
# ## Load dataset

# %%
from src.dataset import TestDataset
from src.config import TestConfig
from torch.utils.data import DataLoader

test_cfg = TestConfig()
test_cfg.reload()
print("\nLoading test dataset...")
test_dataset = TestDataset(
    test_cfg.data_root,
    num_frames=t_cfg.num_frames,
    frame_stride=t_cfg.frame_stride,
    image_size=m_cfg.image_size,
)
test_loader = DataLoader(
    test_dataset,
    batch_size=t_cfg.batch_size,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
)
print(f"Test samples: {len(test_dataset)}")

# %% [markdown]
# ## Inference

# %%
from tqdm.auto import tqdm

print("\nRunning inference...")
predictions = []
checkpoint_classes: list[str] = checkpoint['train_classes']
with torch.no_grad():
    for videos, video_ids in tqdm(test_loader, desc="Inference"):
        videos = videos.to(t_cfg.device)
        logits = inf_model(videos)
        preds = logits.argmax(dim=1)
        for video_id, pred_idx in zip(video_ids.cpu().numpy(), preds.cpu().numpy()):
            pred_class = checkpoint_classes[pred_idx]
            predictions.append((video_id, pred_class))

predictions.sort(key=lambda x: x[0])
print(f"\nTotal predictions: {len(predictions)}")

# %% [markdown]
# ## Save submission

# %%
# TODO: load params from metrics instead of config
submission_name = (
    f"submission_vitb{m_cfg.patch_size}"
    f"_d{m_cfg.depth}h{m_cfg.num_heads}"
    f"_smif{m_cfg.smif_window}"
    f"_lr{t_cfg.lr}"
    f"_bs{t_cfg.batch_size}"
    f"_f{t_cfg.num_frames}s{t_cfg.frame_stride}"
    f"_dr{m_cfg.drop_rate}"
    f"_e{t_cfg.epochs}"
    f"_acc{checkpoint['val_acc']:.4f}"
    f".csv"
)
submission_path = train_saved_chk_dir / Path(submission_name)
with open(submission_path, "w") as f:
    f.write("id,class\n")
    for video_id, pred_class in predictions:
        f.write(f"{video_id},{pred_class}\n")

print("=" * 40)
print(f"Submission saved to: {submission_path}")
